# %%
# !pip install praw
import praw
import pandas as pd
from datetime import datetime
import time
import os

# Reddit API setup
reddit = praw.Reddit(
    client_id="nVQRMRCi-xD3eGHnVYDoZA",
    client_secret="AjU-njuV8mEPrPPFYapqMbHQ6QAfEQ",
    user_agent="university_project:v1.0 (by /u/Ordinary_Cancel9034)")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.3/189.3 kB 7.5 MB/s eta 0:00:00
# ...

# %%
subreddits = ['piratesofthecaribbean', 'nostalgia', 'movies']
query         = 'Dead Men Tell No Tales'
limit         = 10


comments_data = []

for sub_name in subreddits:
    sub = reddit.subreddit(sub_name)
    print(f"\nFetching from r/{sub_name}:")
    for submission in sub.search(query, sort='relevance', time_filter='all', limit=limit):
        print(f"  • {submission.title}  [{submission.id}]")
        # fetch comments
        submission.comments.replace_more(limit=None)
        for c in submission.comments.list():
            comments_data.append({
                'subreddit':    sub_name,
                'post_id':      submission.id,
                'post_title':   submission.title,
                'comment_id':   c.id,
                'comment_time': datetime.fromtimestamp(c.created_utc).strftime('%Y-%m-%d %H:%M:%S'),
                'comment_body': c.body,
                'author':       str(c.author)
            })


df = pd.DataFrame(comments_data)
df.to_csv('pirate5_subreddits_comments.csv', index=False)
print(f"\n✅ Saved {len(df)} comments to 'multi_subreddits_comments.csv'")
# Out:
# WARNING:praw:It appears that you are using PRAW in an asynchronous environment.
# It is strongly recommended to use Async PRAW: https://asyncpraw.readthedocs.io.
# See https://praw.readthedocs.io/en/latest/getting_started/multiple_instances.html#discord-bots-and-asynchronous-environments for more info.
# Fetching from r/piratesofthecaribbean:
# WARNING:praw:It appears that you are using PRAW in an asynchronous environment.
# It is strongly recommended to use Async PRAW: https://asyncpraw.readthedocs.io.
# See https://praw.readthedocs.io/en/latest/getting_started/multiple_instances.html#discord-bots-and-asynchronous-environments for more info.
#
# WARNING:praw:It appears that you are using PRAW in an asynchronous environment.
# It is strongly recommended to use Async PRAW: https://asyncpraw.readthedocs.io.
# See https://praw.readthedocs.io/en/latest/getting_started/multiple_instances.html#discord-bots-and-asynchronous-environments for more info.
# ...

# %%
df
# Out:
#        post_id                                         post_title comment_id  \
# 0      1k324s4  AMA/Q&A Announcement - Peter Stormare - Tuesda...    mnynajz
# 1      1k324s4  AMA/Q&A Announcement - Peter Stormare - Tuesda...    mnynlgu
# 2      1k324s4  AMA/Q&A Announcement - Peter Stormare - Tuesda...    mnyqpx7
# 3      1k324s4  AMA/Q&A Announcement - Peter Stormare - Tuesda...    mnyo7hc
# 4      1k324s4  AMA/Q&A Announcement - Peter Stormare - Tuesda...    mnyna9r
# ...        ...                                                ...        ...
# 11784   p08reb  The Twilight Saga: Breaking Dawn Part II is a ...    h88ppx0
# 11785   p08reb  The Twilight Saga: Breaking Dawn Part II is a ...    h8f6itk
# 11786   p08reb  The Twilight Saga: Breaking Dawn Part II is a ...    h858v4n
# 11787   p08reb  The Twilight Saga: Breaking Dawn Part II is a ...    h85ktzi
# 11788   p08reb  The Twilight Saga: Breaking Dawn Part II is a ...    h87ijrj
#
# ...
